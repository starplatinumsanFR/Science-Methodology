# %%
This final graphic is absolutely AGONISING AND ATROCIOUS I really hesitated before criticizing it, but here we are:

# %% [markdown]
# ![image.png](attachment:e2f56705-7675-40f2-8d12-fd19bac5af86.png)

# %% [markdown]
# Again. The building method is unclear. There's too much data going on, making the cognitive load of this graph very high,
# it's purely a graph made to compare data globally (so not really individually) spanned over years with a color shade that has a bias connotation. The radial format is just in general very unconventional and prefered when the precision in what data we want to show isn't required.
#
# Again, no confidence intervals but what can you expect.
#
# There's so much bloat that this graph is only readable on larger screens or printed in a smaller format on larger papers.
#
# There are no axes that allow for immediate identification of a each degrees, you basically need to look at a shade of the same color and then look at the legend on the right which isn't convienent for fast research, the lack of grid helper for support doesn't help either.
#
# There are too many curves. The monthly details feel a bit redundant because of how the graphic was made, it's incoherent, pick a side, do you want to show precise data or just a global comparaison.
#
# The title was poorly orchestrated as it tries to compare two groups of years but without actually showing split defined cues to isolated both groups, they were kind of merged together, it should have been something more like ''Monthly global mean temperature since 1850 to 2020, the parenthesis has no purpose there.
