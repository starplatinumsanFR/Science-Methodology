# %%
For the following graphic, we will criticize the one about the daily new confirmed covid-19 cases per million people:

# %% [markdown]
# ![image.png](attachment:a95a6562-ac68-4d48-8976-6a31b63a8897.png)

# %% [markdown]
# For this graphic, we have a fewer variety of issues, but the ones that it has are rather major.
# Here is what I found:
#
# First of all, just like the first graphic, no confidence intervals are shown, leaving the precision in its reproductibility in jeopardy...
#
# the Y-axis is absolutely atrocious as it doesn't follow a consistent gap to value ratio. Not only does the graphic breaks out of its chart, but there's a weird variation between 30 and 100 (yes because it doesn't even start at 0 despite having values going below 30) and between 100 and 200 with a smaller gap and an interval of 100.
#
# There are no grid lines for the X-asis.
#
# This graphic has a strong bias as to how it wants to show its data, every small incoherence seems to have been done in order to highlight the variance when there were large increases or drops in covid cases. It seems to have also zoomed in so that at the end we could see a much larger gap of cases between both countries despite it being minimal compared to previous months.
#
# Overall, the graphic needs some strong tweaking, but it isn't AS bad as the previous one.
