# %% [markdown]
# For the next graph, we got a pretty simple one .. or rather too simple? Here's why:

# %% [markdown]
# ![image.png](attachment:971b100a-7dcd-426d-9eff-5e4e3cc44032.png)

# %% [markdown]
# First of all, we have no idea what the sources and collection methods are.
#
# Here the use of colors is very important and the fact that they used black among other colors really accentuates
# it compared to blue and red especially if we want to print them out. It dominates the chart.
# The color palette however is distinct enough I'll give them that.
#
# The axes are not identified and lack quantity labels/units although we can implicitely understand what they are about, it's definitely a huge mistake.
#
# The scale again does not start at 0 but whatever.
#
# The title is absolutely HORRENDOUS as it states basically nothing.
#
# The visual hierarchy of this graph makes it terrible and should not be displayed outside of contexts to show what a poor data viz graphic is.
